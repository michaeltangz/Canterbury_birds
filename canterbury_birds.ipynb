# %%
# import pandas, geopandas, numpy, matplotlib
import pandas as pd
import geopandas as gpd
import numpy as np
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# import csv file from local
cbirds = pd.read_csv('/content/drive/MyDrive/cbirds_project/birds_canterbury.csv')

# %%
cbirds.info
# Out:
# <bound method DataFrame.info of                               GLOBAL UNIQUE IDENTIFIER LAST EDITED DATE  \
# 0      URN:CornellLabOfOrnithology:EBIRD:OBS1604156753       2023/01/11
# 1      URN:CornellLabOfOrnithology:EBIRD:OBS1604300891       2023/01/11
# 2      URN:CornellLabOfOrnithology:EBIRD:OBS1622102585       2023/02/03
# 3      URN:CornellLabOfOrnithology:EBIRD:OBS1611155699       2023/12/11
# 4      URN:CornellLabOfOrnithology:EBIRD:OBS1609319533       2023/01/18
# ...                                                ...              ...
# 75022  URN:CornellLabOfOrnithology:EBIRD:OBS1729275935       2023/05/16
# 75023  URN:CornellLabOfOrnithology:EBIRD:OBS1742729542       2023/06/01
# 75024  URN:CornellLabOfOrnithology:EBIRD:OBS1741721756       2023/05/27
# 75025  URN:CornellLabOfOrnithology:EBIRD:OBS1741724017       2023/05/27
# 75026                            URN:CornellLabOfOrnit              NaN
#
#        TAXONOMIC ORDER CATEGORY  TAXON CONCEPT ID            COMMON NAME  \
# 0               6851.0     spuh  avibase-0DA72A61          albatross sp.
# 1               6851.0     spuh  avibase-0DA72A61          albatross sp.
# 2               6925.0  species  avibase-C1706A8B  Southern Giant-Petrel
# 3               7167.0  species  avibase-13610344    Australasian Gannet
# 4               7167.0  species  avibase-13610344    Australasian Gannet
# ...                ...      ...               ...                    ...
# 75022          27356.0  species  avibase-94A44032      European Starling
# 75023          27356.0  species  avibase-94A44032      European Starling
# 75024          27356.0  species  avibase-94A44032      European Starling
# 75025          27356.0  species  avibase-94A44032      European Starling
# 75026              NaN      NaN               NaN                    NaN
#
#              SCIENTIFIC NAME SUBSPECIES COMMON NAME  \
# 0            Diomedeidae sp.                    NaN
# 1            Diomedeidae sp.                    NaN
# 2      Macronectes giganteus                    NaN
# 3             Morus serrator                    NaN
# 4             Morus serrator                    NaN
# ...                      ...                    ...
# 75022       Sturnus vulgaris                    NaN
# 75023       Sturnus vulgaris                    NaN
# 75024       Sturnus vulgaris                    NaN
# 75025       Sturnus vulgaris                    NaN
# 75026                    NaN                    NaN
#
#       SUBSPECIES SCIENTIFIC NAME EXOTIC CODE  ... EFFORT AREA HA  \
# 0                            NaN         NaN  ...            NaN
# 1                            NaN         NaN  ...            NaN
# 2                            NaN         NaN  ...            NaN
# 3                            NaN         NaN  ...            NaN
# 4                            NaN         NaN  ...            NaN
# ...                          ...         ...  ...            ...
# 75022                        NaN           N  ...            NaN
# 75023                        NaN           N  ...            NaN
# 75024                        NaN           N  ...            NaN
# 75025                        NaN           N  ...            NaN
# 75026                        NaN         NaN  ...            NaN
#
#       NUMBER OBSERVERS ALL SPECIES REPORTED GROUP IDENTIFIER HAS MEDIA  \
# 0                  3.0                  1.0              NaN       0.0
# 1                  1.0                  1.0              NaN       0.0
# 2                 11.0                  0.0         G9510873       0.0
# 3                  1.0                  1.0              NaN       0.0
# 4                  2.0                  1.0         G9515728       0.0
# ...                ...                  ...              ...       ...
# 75022              5.0                  1.0              NaN       0.0
# 75023              1.0                  1.0              NaN       0.0
# 75024              1.0                  1.0              NaN       0.0
# 75025              1.0                  1.0              NaN       0.0
# 75026              NaN                  NaN              NaN       NaN
#
#       APPROVED REVIEWED REASON TRIP COMMENTS  \
# 0          1.0      0.0    NaN           NaN
# 1          1.0      0.0    NaN           NaN
# 2          1.0      0.0    NaN           NaN
# 3          1.0      0.0    NaN           NaN
# 4          1.0      0.0    NaN           NaN
# ...        ...      ...    ...           ...
# 75022      1.0      0.0    NaN           NaN
# 75023      1.0      0.0    NaN           NaN
# 75024      1.0      0.0    NaN           NaN
# 75025      1.0      0.0    NaN           NaN
# 75026      NaN      NaN    NaN           NaN
#
#                               SPECIES COMMENTS
# 0                                          NaN
# 1                                          NaN
# 2      Observed by guide only, Abram Tompkins.
# 3                                          NaN
# 4                                          NaN
# ...                                        ...
# 75022                                      NaN
# 75023                                      NaN
# 75024                                      NaN
# 75025                                      NaN
# 75026                                      NaN
#
# [75027 rows x 49 columns]>

# %%
cbirds.columns
# Out:
# Index(['GLOBAL UNIQUE IDENTIFIER', 'LAST EDITED DATE', 'TAXONOMIC ORDER',
#        'CATEGORY', 'TAXON CONCEPT ID', 'COMMON NAME', 'SCIENTIFIC NAME',
#        'SUBSPECIES COMMON NAME', 'SUBSPECIES SCIENTIFIC NAME', 'EXOTIC CODE',
#        'OBSERVATION COUNT', 'BREEDING CODE', 'BREEDING CATEGORY',
#        'BEHAVIOR CODE', 'AGE/SEX', 'COUNTRY', 'COUNTRY CODE', 'STATE',
#        'STATE CODE', 'COUNTY', 'COUNTY CODE', 'IBA CODE', 'BCR CODE',
#        'USFWS CODE', 'ATLAS BLOCK', 'LOCALITY', 'LOCALITY ID', 'LOCALITY TYPE',
#        'LATITUDE', 'LONGITUDE', 'OBSERVATION DATE',
#        'TIME OBSERVATIONS STARTED', 'OBSERVER ID', 'SAMPLING EVENT IDENTIFIER',
#        'PROTOCOL TYPE', 'PROTOCOL CODE', 'PROJECT CODE', 'DURATION MINUTES',
#        'EFFORT DISTANCE KM', 'EFFORT AREA HA', 'NUMBER OBSERVERS',
#        'ALL SPECIES REPORTED', 'GROUP IDENTIFIER', 'HAS MEDIA', 'APPROVED',
#        'REVIEWED', 'REASON', 'TRIP COMMENTS', 'SPECIES COMMENTS'],
#       dtype='object')

# %%
cbirds['SUBSPECIES SCIENTIFIC NAME'].value_counts()
# Out:
# SUBSPECIES SCIENTIFIC NAME
# Columba livia (Feral Pigeon)                  1103
# Chroicocephalus novaehollandiae scopulinus     525
# Petroica macrocephala [macrocephala Group]     176
# Anas platyrhynchos (Domestic type)             120
# Cairina moschata (Domestic type)                66
# Anser anser (Domestic type)                     58
# Phalacrocorax carbo novaehollandiae             54
# Diomedea antipodensis gibsoni                    6
# Thalassarche cauta steadi                        3
# Thalassarche melanophris melanophris             3
# Ardea alba modesta                               3
# Todiramphus sanctus vagans                       2
# Gallus gallus (Domestic type)                    2
# Limosa lapponica [baueri Group]                  1
# Vanellus miles novaehollandiae                   1
# Meleagris gallopavo (Domestic type)              1
# Name: count, dtype: int64

# %%
cbirds.shape
# Out:
# (75027, 49)

# %%
cbirds['COMMON NAME'].value_counts()
# Out:
# COMMON NAME
# House Sparrow               3988
# Eurasian Blackbird          3636
# Silvereye                   3180
# European Starling           3103
# Kelp Gull                   2890
#                             ...
# Yellow-eyed Penguin            1
# Southern Giant-Petrel          1
# Gray-backed Storm-Petrel       1
# Rook                           1
# Curlew Sandpiper               1
# Name: count, Length: 171, dtype: int64

# %%
#
cbirds['COMMON NAME'].value_counts().hist(bins=50)
# Out:
# <Axes: >

# %%
#cbirds['COMMON NAME'].unique()

# %%
# plot the number of distribution of bird species
cbirds['COMMON NAME'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='COMMON NAME'>

# %%
# fileter out the bird species < 1
#cbirds_filtered = cbirds[cbirds['COMMON NAME'].value_counts() > 1]

# %%
# fileter out the bird species < 1
cbirds_filtered = cbirds.groupby('COMMON NAME').filter(lambda x: len(x) > 2)

# %%
cbirds_filtered['COMMON NAME'].value_counts()
# Out:
# COMMON NAME
# House Sparrow                     3988
# Eurasian Blackbird                3636
# Silvereye                         3180
# European Starling                 3103
# Kelp Gull                         2890
#                                   ...
# Buller's Albatross                   4
# Black-browed Albatross               4
# parakeet sp.                         4
# Golden Pheasant                      3
# Southern/Northern Giant-Petrel       3
# Name: count, Length: 152, dtype: int64

# %%
cbirds_filtered['COMMON NAME'].unique()
# Out:
# array(['albatross sp.', 'Australasian Gannet', 'Australian Magpie',
#        'New Zealand Pipit', 'Black-browed Albatross', 'Black-billed Gull',
#        'Black-fronted Tern', 'Black Swan', "Buller's Albatross",
#        "Buller's Shearwater", 'California Quail', 'Canada Goose',
#        'Cape Petrel', 'Caspian Tern', 'Cirl Bunting', 'Common Chaffinch',
#        'Double-banded Plover', 'Dunnock', 'Eurasian Blackbird',
#        'European Goldfinch', 'European Greenfinch', 'European Starling',
#        'Fluttering Shearwater', 'Great Cormorant', 'Gray Teal',
#        'Gray Gerygone', 'House Sparrow', "Hutton's Shearwater",
#        'Kelp Gull', 'Little Pied Cormorant', 'Little Owl', 'Mallard',
#        'Masked Lapwing', 'New Zealand Bellbird', 'New Zealand Falcon',
#        'New Zealand Fantail', 'New Zealand Pigeon', 'South Island Robin',
#        'New Zealand Scaup', 'Northern Giant-Petrel', 'Pacific Reef-Heron',
#        'Paradise Shelduck', 'passerine sp.', 'Pied Cormorant',
#        'Pied Stilt', 'Pipipi', 'Procellaria sp.', 'Rock Pigeon',
#        'Southern Royal Albatross', 'Northern Royal Albatross',
#        'Royal Spoonbill', 'Ruddy Turnstone', 'Sacred Kingfisher',
#        "Salvin's Albatross", 'Shining Bronze-Cuckoo', 'shearwater sp.',
#        'Silver Gull', 'Silvereye', 'Eurasian Skylark',
#        'small albatross sp.', 'South Island Oystercatcher', 'Song Thrush',
#        'Spotted Shag', 'Swamp Harrier', 'Tomtit', 'Tui',
#        'Variable Oystercatcher', 'Snowy/Tristan/Antipodean Albatross',
#        'Welcome Swallow', 'Westland Petrel', 'White-capped Albatross',
#        'White-faced Heron', 'White-fronted Tern',
#        'Mallard x Pacific Black Duck (hybrid)',
#        'Silver/Black-billed Gull', 'Tui/New Zealand Bellbird',
#        'Yellowhammer', 'Anas sp.', 'Australasian Shoveler',
#        'Black-fronted Dotterel', 'Eurasian Coot', 'Graylag Goose',
#        'Lesser Redpoll', 'Long-tailed Koel', 'Morepork',
#        'New Zealand Kaka', 'Pacific Black Duck', 'Parasitic Jaeger',
#        'Australasian Swamphen', 'Rifleman', 'Yellow-crowned Parakeet',
#        'African Collared-Dove', 'Bar-tailed Godwit', 'Black Stilt',
#        'Eastern Cattle Egret', 'Indian Peafowl', 'Great Crested Grebe',
#        'Great Egret', 'Little Black Cormorant', 'Mute Swan',
#        'oystercatcher sp.', 'Pectoral Sandpiper', 'Red Knot',
#        'Ring-necked Pheasant', 'Sharp-tailed Sandpiper', 'Wild Turkey',
#        'Wrybill', 'Pied x Black Stilt (hybrid)',
#        'South Island x Variable Oystercatcher (hybrid)',
#        'Australasian Bittern', "Baillon's Crake", 'Cape Barren Goose',
#        'cormorant sp.', 'jaeger sp.', 'Little Penguin', 'Little Tern',
#        'Muscovy Duck x Mallard (hybrid)', 'Muscovy Duck',
#        'Red-necked Stint', 'Sooty Shearwater', 'Sulphur-crested Cockatoo',
#        'Graylag x Canada Goose (hybrid)', 'bird sp.',
#        'Great Spotted Kiwi', 'Greater Sand-Plover', 'Helmeted Guineafowl',
#        'Kea', 'large albatross sp.', 'Long-toed Stint',
#        "Malherbe's Parakeet", 'Marsh Sandpiper', 'Pacific Golden-Plover',
#        'Spotted Dove', 'Southern/Northern Giant-Petrel', 'Yellowhead',
#        'Chukar', 'duck sp.', 'South Island Wren', 'Antipodean Albatross',
#        'Erect-crested Penguin', 'gull sp.',
#        'Northern/Southern Royal Albatross',
#        "Hutton's/Fluttering Shearwater", 'Sanderling', 'Golden Pheasant',
#        'waterfowl sp.', 'Northern Shoveler', 'White-winged Tern',
#        'Short-tailed Shearwater', 'Little Egret', 'New Zealand Grebe',
#        'parakeet sp.'], dtype=object)

# %%
# check the unique of bcr code
#cbirds_filtered['BCR CODE']

# %%
cbirds_filtered.columns
# Out:
# Index(['GLOBAL UNIQUE IDENTIFIER', 'LAST EDITED DATE', 'TAXONOMIC ORDER',
#        'CATEGORY', 'TAXON CONCEPT ID', 'COMMON NAME', 'SCIENTIFIC NAME',
#        'SUBSPECIES COMMON NAME', 'SUBSPECIES SCIENTIFIC NAME', 'EXOTIC CODE',
#        'OBSERVATION COUNT', 'BREEDING CODE', 'BREEDING CATEGORY',
#        'BEHAVIOR CODE', 'AGE/SEX', 'COUNTRY', 'COUNTRY CODE', 'STATE',
#        'STATE CODE', 'COUNTY', 'COUNTY CODE', 'IBA CODE', 'BCR CODE',
#        'USFWS CODE', 'ATLAS BLOCK', 'LOCALITY', 'LOCALITY ID', 'LOCALITY TYPE',
#        'LATITUDE', 'LONGITUDE', 'OBSERVATION DATE',
#        'TIME OBSERVATIONS STARTED', 'OBSERVER ID', 'SAMPLING EVENT IDENTIFIER',
#        'PROTOCOL TYPE', 'PROTOCOL CODE', 'PROJECT CODE', 'DURATION MINUTES',
#        'EFFORT DISTANCE KM', 'EFFORT AREA HA', 'NUMBER OBSERVERS',
#        'ALL SPECIES REPORTED', 'GROUP IDENTIFIER', 'HAS MEDIA', 'APPROVED',
#        'REVIEWED', 'REASON', 'TRIP COMMENTS', 'SPECIES COMMENTS'],
#       dtype='object')

# %%
# convert 'last edited date' into date formate
cbirds_filtered[['LAST EDITED DATE']] = pd.to_datetime(cbirds_filtered['LAST EDITED DATE'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-90-480476d78ddd> in <cell line: 2>()
#       1 # convert 'last edited date' into date formate
# ----> 2 cbirds_filtered[['LAST EDITED DATE']] = pd.to_datetime(cbirds_filtered['LAST EDITED DATE'])
#
# /usr/local/lib/python3.10/dist-packages/geopandas/geodataframe.py in __setitem__(self, key, value)
#    1817                     stacklevel=2,
#    1818                 )
# -> 1819         super().__setitem__(key, value)
#    1820
#    1821     #
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __setitem__(self, key, value)
#    4077             self._setitem_frame(key, value)
#    4078         elif isinstance(key, (Series, np.ndarray, list, Index)):
# -> 4079             self._setitem_array(key, value)
#    4080         elif isinstance(value, DataFrame):
#    4081             self._set_item_frame_value(key, value)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in _setitem_array(self, key, value)
#    4136
#    4137             else:
# -> 4138                 self._iset_not_inplace(key, value)
#    4139
#    4140     def _iset_not_inplace(self, key, value):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in _iset_not_inplace(self, key, value)
#    4155         if self.columns.is_unique:
#    4156             if np.shape(value)[-1] != len(key):
# -> 4157                 raise ValueError("Columns must be same length as key")
#    4158
#    4159             for i, col in enumerate(key):
#
# ValueError: Columns must be same length as key

# %%
# create month column from 'last edited date'
cbirds_filtered['Last Edited Month'] = cbirds_filtered['LAST EDITED DATE'].dt.month

# %%
cbirds_filtered.Month.unique()
# Out:
# array([ 1, 12, 10,  3,  9,  2,  7, 11,  5,  8,  4,  6], dtype=int32)

# %%
cbirds_filtered['OBSERVATION DATE'] = pd.to_datetime(cbirds_filtered['OBSERVATION DATE'])

# %%
cbirds_filtered['obs_month'] = cbirds_filtered['OBSERVATION DATE'].dt.month

# %%
cbirds_filtered.obs_month.unique()
# Out:
# array([1, 2, 3, 4, 5], dtype=int32)

# %%
cbirds_filtered['TAXON CONCEPT ID'].value_counts()
# Out:
# TAXON CONCEPT ID
# avibase-240E3390    3988
# avibase-88BB4F2A    3636
# avibase-EA151AD8    3180
# avibase-94A44032    3103
# avibase-E6536E4E    2890
#                     ...
# avibase-3AA939ED       2
# avibase-47AF130E       1
# avibase-EDEC5EC5       1
# avibase-AD2AE997       1
# avibase-F9FCB9FF       1
# Name: count, Length: 164, dtype: int64

# %%
cbirds_filtered['EXOTIC CODE'].value_counts()
# Out:
# EXOTIC CODE
# N    33347
# X      241
# P      179
# Name: count, dtype: int64

# %%
cbirds_filtered['OBSERVATION COUNT'].value_counts()
# Out:
# OBSERVATION COUNT
# 1      22008
# 2      15289
# 3       7098
# 4       5444
# 5       3747
#        ...
# 427        1
# 139        1
# 418        1
# 205        1
# 176        1
# Name: count, Length: 293, dtype: int64

# %%
cbirds_filtered['BCR CODE'].unique()
# Out:
# array([nan])

# %%
# drop unuse cols
cbirds_filtered.drop(['GLOBAL UNIQUE IDENTIFIER', 'SUBSPECIES SCIENTIFIC NAME','BCR CODE','USFWS CODE','TAXON CONCEPT ID','AGE/SEX','COUNTRY','COUNTRY CODE','STATE','OBSERVER ID','SAMPLING EVENT IDENTIFIER','PROTOCOL TYPE','PROTOCOL CODE','PROJECT CODE','DURATION MINUTES','EFFORT DISTANCE KM','EFFORT AREA HA','NUMBER OBSERVERS','GROUP IDENTIFIER','HAS MEDIA','REVIEWED','REASON','TRIP COMMENTS','SPECIES COMMENTS','SUBSPECIES COMMON NAME','ALL SPECIES REPORTED'], axis=1, inplace=True)

# %%
cbirds_filtered.head()
# Out:
#   LAST EDITED DATE  TAXONOMIC ORDER CATEGORY          COMMON NAME  \
# 0       2023/01/11           6851.0     spuh        albatross sp.
# 1       2023/01/11           6851.0     spuh        albatross sp.
# 3       2023/12/11           7167.0  species  Australasian Gannet
# 4       2023/01/18           7167.0  species  Australasian Gannet
# 5       2023/10/17           7167.0  species  Australasian Gannet
#
#    SCIENTIFIC NAME EXOTIC CODE OBSERVATION COUNT BREEDING CODE  \
# 0  Diomedeidae sp.         NaN                 1           NaN
# 1  Diomedeidae sp.         NaN                 4           NaN
# 3   Morus serrator         NaN                 1           NaN
# 4   Morus serrator         NaN                 1           NaN
# 5   Morus serrator         NaN                 2           NaN
#
#   BREEDING CATEGORY BEHAVIOR CODE  ...        IBA CODE ATLAS BLOCK  \
# 0               NaN           NaN  ...  BIRDLIFE_44601         NaN
# 1               NaN           NaN  ...  BIRDLIFE_44599     blkCI59
# 3               NaN           NaN  ...  BIRDLIFE_44601     blkCL57
# 4               NaN           NaN  ...  BIRDLIFE_44601     blkCL56
# 5               NaN           NaN  ...  BIRDLIFE_44601         NaN
#
#                                             LOCALITY LOCALITY ID  \
# 0  Hikurangi Marine Reserve, Kaikōura NZ-Canterbu...   L22166918
# 1  North of Clarence River Mouth, Kaikōura NZ-Can...   L22168688
# 3                          Kaikoura--town waterfront    L1249759
# 4  1200 Alpine Pacific Touring Route, Peketā, Can...   L22249885
# 5             Kaikoura South Coast--Oaro River Mouth   L12602431
#
#   LOCALITY TYPE   LATITUDE   LONGITUDE OBSERVATION DATE  \
# 0             P -42.458124  173.554744       2023/01/12
# 1             P -42.171416  173.932336       2023/01/12
# 3             H -42.402038  173.682518       2023/01/21
# 4             P -42.451887  173.568536       2023/01/18
# 5             H -42.513964  173.507146       2023/01/15
#
#    TIME OBSERVATIONS STARTED  APPROVED
# 0                   11:41:00       1.0
# 1                   13:16:00       1.0
# 3                   11:59:00       1.0
# 4                   11:02:00       1.0
# 5                   12:05:00       1.0
#
# [5 rows x 23 columns]

# %%
#

# %%
# further drop
#cbirds_filtered = cbirds_filtered.drop(['SUBSPECIES COMMON NAME','ATLAS BLOCK'], axis=1)

# %%
cbirds_filtered.columns
# Out:
# Index(['LAST EDITED DATE', 'TAXONOMIC ORDER', 'CATEGORY', 'COMMON NAME',
#        'SCIENTIFIC NAME', 'EXOTIC CODE', 'OBSERVATION COUNT', 'BREEDING CODE',
#        'BREEDING CATEGORY', 'BEHAVIOR CODE', 'STATE CODE', 'COUNTY',
#        'COUNTY CODE', 'IBA CODE', 'ATLAS BLOCK', 'LOCALITY', 'LOCALITY ID',
#        'LOCALITY TYPE', 'LATITUDE', 'LONGITUDE', 'OBSERVATION DATE',
#        'TIME OBSERVATIONS STARTED', 'APPROVED'],
#       dtype='object')

# %%
cbirds_filtered.head()
# Out:
#   LAST EDITED DATE  TAXONOMIC ORDER CATEGORY          COMMON NAME  \
# 0       2023/01/11           6851.0     spuh        albatross sp.
# 1       2023/01/11           6851.0     spuh        albatross sp.
# 3       2023/12/11           7167.0  species  Australasian Gannet
# 4       2023/01/18           7167.0  species  Australasian Gannet
# 5       2023/10/17           7167.0  species  Australasian Gannet
#
#    SCIENTIFIC NAME EXOTIC CODE OBSERVATION COUNT BREEDING CODE  \
# 0  Diomedeidae sp.         NaN                 1           NaN
# 1  Diomedeidae sp.         NaN                 4           NaN
# 3   Morus serrator         NaN                 1           NaN
# 4   Morus serrator         NaN                 1           NaN
# 5   Morus serrator         NaN                 2           NaN
#
#   BREEDING CATEGORY BEHAVIOR CODE  ...        IBA CODE ATLAS BLOCK  \
# 0               NaN           NaN  ...  BIRDLIFE_44601         NaN
# 1               NaN           NaN  ...  BIRDLIFE_44599     blkCI59
# 3               NaN           NaN  ...  BIRDLIFE_44601     blkCL57
# 4               NaN           NaN  ...  BIRDLIFE_44601     blkCL56
# 5               NaN           NaN  ...  BIRDLIFE_44601         NaN
#
#                                             LOCALITY LOCALITY ID  \
# 0  Hikurangi Marine Reserve, Kaikōura NZ-Canterbu...   L22166918
# 1  North of Clarence River Mouth, Kaikōura NZ-Can...   L22168688
# 3                          Kaikoura--town waterfront    L1249759
# 4  1200 Alpine Pacific Touring Route, Peketā, Can...   L22249885
# 5             Kaikoura South Coast--Oaro River Mouth   L12602431
#
#   LOCALITY TYPE   LATITUDE   LONGITUDE OBSERVATION DATE  \
# 0             P -42.458124  173.554744       2023/01/12
# 1             P -42.171416  173.932336       2023/01/12
# 3             H -42.402038  173.682518       2023/01/21
# 4             P -42.451887  173.568536       2023/01/18
# 5             H -42.513964  173.507146       2023/01/15
#
#    TIME OBSERVATIONS STARTED  APPROVED
# 0                   11:41:00       1.0
# 1                   13:16:00       1.0
# 3                   11:59:00       1.0
# 4                   11:02:00       1.0
# 5                   12:05:00       1.0
#
# [5 rows x 23 columns]

# %%
# count the number of 'Bar-tailed Godwit
god_wit = cbirds_filtered[cbirds_filtered['COMMON NAME'] == 'Bar-tailed Godwit']

# %%
god_wit.head()
# Out:
#      LAST EDITED DATE  TAXONOMIC ORDER CATEGORY        COMMON NAME  \
# 4682       2023/01/12           6000.0  species  Bar-tailed Godwit
# 4683       2022/12/31           6000.0  species  Bar-tailed Godwit
# 4684       2023/01/04           6000.0  species  Bar-tailed Godwit
# 4685       2023/01/27           6000.0  species  Bar-tailed Godwit
# 4686       2023/01/27           6000.0  species  Bar-tailed Godwit
#
#        SCIENTIFIC NAME EXOTIC CODE OBSERVATION COUNT BREEDING CODE  \
# 4682  Limosa lapponica         NaN                10           NaN
# 4683  Limosa lapponica         NaN                 2           NaN
# 4684  Limosa lapponica         NaN                23           NaN
# 4685  Limosa lapponica         NaN               120           NaN
# 4686  Limosa lapponica         NaN                37           NaN
#
#      BREEDING CATEGORY BEHAVIOR CODE  ...        IBA CODE ATLAS BLOCK  \
# 4682               NaN           NaN  ...  BIRDLIFE_44605         NaN
# 4683               NaN           NaN  ...  BIRDLIFE_44605         NaN
# 4684               NaN           NaN  ...  BIRDLIFE_44605     blkCU49
# 4685               NaN           NaN  ...  BIRDLIFE_44605         NaN
# 4686               NaN           NaN  ...  BIRDLIFE_44641         NaN
#
#                                                LOCALITY LOCALITY ID  \
# 4682                               Ashley River Estuary     L523080
# 4683  Ashley Rakahuri Regional Park, Waikuku Beach N...   L21993117
# 4684                           Ashley Estuary south end     L620463
# 4685                               Ashley River Estuary     L523080
# 4686                    Waikuku Beach--beach & offshore    L6658955
#
#      LOCALITY TYPE   LATITUDE   LONGITUDE OBSERVATION DATE  \
# 4682             H -43.276705  172.718811       2023/01/12
# 4683             P -43.282429  172.721391       2023/01/01
# 4684             H -43.280705  172.721214       2023/01/05
# 4685             H -43.276705  172.718811       2023/01/28
# 4686             H -43.283566  172.723763       2023/01/28
#
#       TIME OBSERVATIONS STARTED  APPROVED
# 4682                   12:05:00       1.0
# 4683                   12:26:00       1.0
# 4684                   09:10:00       1.0
# 4685                   13:58:00       1.0
# 4686                   10:37:00       1.0
#
# [5 rows x 23 columns]

# %%
god_wit.dtypes
# Out:
# LAST EDITED DATE              object
# TAXONOMIC ORDER              float64
# CATEGORY                      object
# COMMON NAME                   object
# SCIENTIFIC NAME               object
# EXOTIC CODE                   object
# OBSERVATION COUNT             object
# BREEDING CODE                 object
# BREEDING CATEGORY             object
# BEHAVIOR CODE                 object
# STATE CODE                    object
# COUNTY                        object
# COUNTY CODE                   object
# IBA CODE                      object
# ATLAS BLOCK                   object
# LOCALITY                      object
# LOCALITY ID                   object
# LOCALITY TYPE                 object
# LATITUDE                     float64
# LONGITUDE                    float64
# OBSERVATION DATE              object
# TIME OBSERVATIONS STARTED     object
# APPROVED                     float64
# dtype: object

# %%
# check the unique of god_wit
god_wit['OBSERVATION COUNT'].unique()
# Out:
# array(['10', '2', '23', '120', '37', '3', '9', 'X', '22', '7', '18', '17',
#        '12', '19', '20', '8', '25', '4', '28', '900', '60', '41', '55',
#        '16', '51', '40', '34', '100', '1', '200', '6', '24', '30', '15',
#        '148', '52', '13', '75', '26', '21', '50', '168', '150', '35',
#        '126', '56', '43', '58', '800', '5', '32', '45', '44', '38', '235',
#        '140'], dtype=object)

# %%
# set the 'X' into '1'
god_wit['OBSERVATION COUNT'] = god_wit['OBSERVATION COUNT'].replace('X', '1')
# Out:
# <ipython-input-32-3dd2e09d7bf8>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   god_wit['OBSERVATION COUNT'] = god_wit['OBSERVATION COUNT'].replace('X', '1')

# %%
# convert the observation count into int
god_wit['OBSERVATION COUNT'] = god_wit['OBSERVATION COUNT'].astype(int)
# Out:
# <ipython-input-33-43ef11e13598>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   god_wit['OBSERVATION COUNT'] = god_wit['OBSERVATION COUNT'].astype(int)

# %%
god_wit.dtypes
# Out:
# LAST EDITED DATE              object
# TAXONOMIC ORDER              float64
# CATEGORY                      object
# COMMON NAME                   object
# SCIENTIFIC NAME               object
# EXOTIC CODE                   object
# OBSERVATION COUNT              int64
# BREEDING CODE                 object
# BREEDING CATEGORY             object
# BEHAVIOR CODE                 object
# STATE CODE                    object
# COUNTY                        object
# COUNTY CODE                   object
# IBA CODE                      object
# ATLAS BLOCK                   object
# LOCALITY                      object
# LOCALITY ID                   object
# LOCALITY TYPE                 object
# LATITUDE                     float64
# LONGITUDE                    float64
# OBSERVATION DATE              object
# TIME OBSERVATIONS STARTED     object
# APPROVED                     float64
# dtype: object

# %%
# count the sum of observation_number
god_wit['OBSERVATION COUNT'].sum()
# Out:
# 11005

# %%
cbirds_filtered['COMMON NAME'].unique()
# Out:
# array(['albatross sp.', 'Australasian Gannet', 'Australian Magpie',
#        'New Zealand Pipit', 'Black-browed Albatross', 'Black-billed Gull',
#        'Black-fronted Tern', 'Black Swan', "Buller's Albatross",
#        "Buller's Shearwater", 'California Quail', 'Canada Goose',
#        'Cape Petrel', 'Caspian Tern', 'Cirl Bunting', 'Common Chaffinch',
#        'Double-banded Plover', 'Dunnock', 'Eurasian Blackbird',
#        'European Goldfinch', 'European Greenfinch', 'European Starling',
#        'Fluttering Shearwater', 'Great Cormorant', 'Gray Teal',
#        'Gray Gerygone', 'House Sparrow', "Hutton's Shearwater",
#        'Kelp Gull', 'Little Pied Cormorant', 'Little Owl', 'Mallard',
#        'Masked Lapwing', 'New Zealand Bellbird', 'New Zealand Falcon',
#        'New Zealand Fantail', 'New Zealand Pigeon', 'South Island Robin',
#        'New Zealand Scaup', 'Northern Giant-Petrel', 'Pacific Reef-Heron',
#        'Paradise Shelduck', 'passerine sp.', 'Pied Cormorant',
#        'Pied Stilt', 'Pipipi', 'Procellaria sp.', 'Rock Pigeon',
#        'Southern Royal Albatross', 'Northern Royal Albatross',
#        'Royal Spoonbill', 'Ruddy Turnstone', 'Sacred Kingfisher',
#        "Salvin's Albatross", 'Shining Bronze-Cuckoo', 'shearwater sp.',
#        'Silver Gull', 'Silvereye', 'Eurasian Skylark',
#        'small albatross sp.', 'South Island Oystercatcher', 'Song Thrush',
#        'Spotted Shag', 'Swamp Harrier', 'Tomtit', 'Tui',
#        'Variable Oystercatcher', 'Snowy/Tristan/Antipodean Albatross',
#        'Welcome Swallow', 'Westland Petrel', 'White-capped Albatross',
#        'White-faced Heron', 'White-fronted Tern',
#        'Mallard x Pacific Black Duck (hybrid)',
#        'Silver/Black-billed Gull', 'Tui/New Zealand Bellbird',
#        'Yellowhammer', 'Anas sp.', 'Australasian Shoveler',
#        'Black-fronted Dotterel', 'Eurasian Coot', 'Graylag Goose',
#        'Lesser Redpoll', 'Long-tailed Koel', 'Morepork',
#        'New Zealand Kaka', 'Pacific Black Duck', 'Parasitic Jaeger',
#        'Australasian Swamphen', 'Rifleman', 'Yellow-crowned Parakeet',
#        'African Collared-Dove', 'Bar-tailed Godwit', 'Black Stilt',
#        'Eastern Cattle Egret', 'Indian Peafowl', 'Great Crested Grebe',
#        'Great Egret', 'Little Black Cormorant', 'Mute Swan',
#        'oystercatcher sp.', 'Pectoral Sandpiper', 'Red Knot',
#        'Ring-necked Pheasant', 'Sharp-tailed Sandpiper', 'Wild Turkey',
#        'Wrybill', 'Pied x Black Stilt (hybrid)',
#        'South Island x Variable Oystercatcher (hybrid)',
#        'Australasian Bittern', "Baillon's Crake", 'Cape Barren Goose',
#        'cormorant sp.', 'jaeger sp.', 'Little Penguin', 'Little Tern',
#        'Muscovy Duck x Mallard (hybrid)', 'Muscovy Duck',
#        'Red-necked Stint', 'Sooty Shearwater', 'Sulphur-crested Cockatoo',
#        'Graylag x Canada Goose (hybrid)', 'bird sp.',
#        'Great Spotted Kiwi', 'Greater Sand-Plover', 'Helmeted Guineafowl',
#        'Kea', 'large albatross sp.', 'Long-toed Stint',
#        "Malherbe's Parakeet", 'Marsh Sandpiper', 'Pacific Golden-Plover',
#        'Spotted Dove', 'Southern/Northern Giant-Petrel', 'Yellowhead',
#        'Chukar', 'duck sp.', 'South Island Wren', 'Antipodean Albatross',
#        'Erect-crested Penguin', 'gull sp.',
#        'Northern/Southern Royal Albatross',
#        "Hutton's/Fluttering Shearwater", 'Sanderling', 'Golden Pheasant',
#        'waterfowl sp.', 'Northern Shoveler', 'White-winged Tern',
#        'Short-tailed Shearwater', 'Little Egret', 'New Zealand Grebe',
#        'parakeet sp.'], dtype=object)

# %%
#extract the migration birds type form common_name
migration_birds_list = ['Bar-tailed Godwit','Pacific Golden-Plover','Ruddy Turnstone','Sharp-tailed Sandpiper','Red-necked Stint','Little Tern','white-winged tern','Southern/Northern Giant-Petrel','Short-tailed Shearwater','Eastern Cattle Egret']

# %%
migration_birds = cbirds_filtered[cbirds_filtered['COMMON NAME'].isin(migration_birds_list)]

# %%
migration_birds.shape
# Out:
# (536, 23)

# %%
migration_birds['COMMON NAME'].value_counts()
# Out:
# COMMON NAME
# Bar-tailed Godwit                 221
# Ruddy Turnstone                    83
# Eastern Cattle Egret               59
# Red-necked Stint                   58
# Sharp-tailed Sandpiper             41
# Pacific Golden-Plover              36
# Little Tern                        31
# Short-tailed Shearwater             4
# Southern/Northern Giant-Petrel      3
# Name: count, dtype: int64

# %%
migration_birds.head()
# Out:
#      LAST EDITED DATE  TAXONOMIC ORDER CATEGORY        COMMON NAME  \
# 820        2023/01/10           6125.0  species    Ruddy Turnstone
# 821        2023/01/10           6125.0  species    Ruddy Turnstone
# 822        2023/01/11           6125.0  species    Ruddy Turnstone
# 4682       2023/01/12           6000.0  species  Bar-tailed Godwit
# 4683       2022/12/31           6000.0  species  Bar-tailed Godwit
#
#          SCIENTIFIC NAME EXOTIC CODE OBSERVATION COUNT BREEDING CODE  \
# 820   Arenaria interpres         NaN                17           NaN
# 821   Arenaria interpres         NaN                17           NaN
# 822   Arenaria interpres         NaN                 1           NaN
# 4682    Limosa lapponica         NaN                10           NaN
# 4683    Limosa lapponica         NaN                 2           NaN
#
#      BREEDING CATEGORY BEHAVIOR CODE  ...        IBA CODE ATLAS BLOCK  \
# 820                NaN           NaN  ...  BIRDLIFE_44601         NaN
# 821                NaN           NaN  ...  BIRDLIFE_44601         NaN
# 822                NaN           NaN  ...  BIRDLIFE_44601         NaN
# 4682               NaN           NaN  ...  BIRDLIFE_44605         NaN
# 4683               NaN           NaN  ...  BIRDLIFE_44605         NaN
#
#                                                LOCALITY LOCALITY ID  \
# 820                              Kaikoura--Armers Beach    L1399210
# 821                              Kaikoura--Armers Beach    L1399210
# 822                    Kaikoura--Point Kean Seal Colony     L558781
# 4682                               Ashley River Estuary     L523080
# 4683  Ashley Rakahuri Regional Park, Waikuku Beach N...   L21993117
#
#      LOCALITY TYPE   LATITUDE   LONGITUDE OBSERVATION DATE  \
# 820              H -42.419497  173.706808       2023/01/09
# 821              H -42.419497  173.706808       2023/01/09
# 822              H -42.423583  173.716893       2023/01/12
# 4682             H -43.276705  172.718811       2023/01/12
# 4683             P -43.282429  172.721391       2023/01/01
#
#       TIME OBSERVATIONS STARTED  APPROVED
# 820                    20:33:00       1.0
# 821                    20:33:00       1.0
# 822                    12:52:00       1.0
# 4682                   12:05:00       1.0
# 4683                   12:26:00       1.0
#
# [5 rows x 23 columns]

# %%
migration_birds['OBSERVATION COUNT'].unique()
# Out:
# array(['17', '1', '10', '2', '23', '120', '37', '3', '9', 'X', '22', '7',
#        '18', '12', '19', '20', '8', '25', '4', '28', '900', '60', '41',
#        '55', '16', '51', '40', '34', '100', '200', '6', '33', '5', '30',
#        '15', '11', '32', '45', '38', '42', '14', '24', '148', '52', '13',
#        '75', '26', '21', '50', '168', '150', '35', '126', '56', '43',
#        '58', '800', '64', '44', '235', '27', '140'], dtype=object)

# %%
migration_birds['OBSERVATION COUNT'] = migration_birds['OBSERVATION COUNT'].replace('X', '1')
# Out:
# <ipython-input-43-5b22bf083225>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   migration_birds['OBSERVATION COUNT'] = migration_birds['OBSERVATION COUNT'].replace('X', '1')

# %%
migration_birds['OBSERVATION COUNT'] = migration_birds['OBSERVATION COUNT'].astype(int)
# Out:
# <ipython-input-44-31f499884218>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   migration_birds['OBSERVATION COUNT'] = migration_birds['OBSERVATION COUNT'].astype(int)

# %%
migration_birds['OBSERVATION COUNT'].sum()
# Out:
# 13880

# %%
cbirds_filtered.shape
# Out:
# (74997, 23)

# %%
# create new column assign 'M' to the rows which isin migration_birds_list otherwise to 'N'
cbirds_filtered['Migration_type'] = np.where(cbirds_filtered['COMMON NAME'].isin(migration_birds_list), 'M', 'N')

# %%
#cbirds_filtered[cbirds_filtered['COMMON NAME'] == 'Tui']

# %%
cbirds_filtered.head()
# Out:
#   LAST EDITED DATE  TAXONOMIC ORDER CATEGORY          COMMON NAME  \
# 0       2023/01/11           6851.0     spuh        albatross sp.
# 1       2023/01/11           6851.0     spuh        albatross sp.
# 3       2023/12/11           7167.0  species  Australasian Gannet
# 4       2023/01/18           7167.0  species  Australasian Gannet
# 5       2023/10/17           7167.0  species  Australasian Gannet
#
#    SCIENTIFIC NAME EXOTIC CODE OBSERVATION COUNT BREEDING CODE  \
# 0  Diomedeidae sp.         NaN                 1           NaN
# 1  Diomedeidae sp.         NaN                 4           NaN
# 3   Morus serrator         NaN                 1           NaN
# 4   Morus serrator         NaN                 1           NaN
# 5   Morus serrator         NaN                 2           NaN
#
#   BREEDING CATEGORY BEHAVIOR CODE  ... ATLAS BLOCK  \
# 0               NaN           NaN  ...         NaN
# 1               NaN           NaN  ...     blkCI59
# 3               NaN           NaN  ...     blkCL57
# 4               NaN           NaN  ...     blkCL56
# 5               NaN           NaN  ...         NaN
#
#                                             LOCALITY LOCALITY ID  \
# 0  Hikurangi Marine Reserve, Kaikōura NZ-Canterbu...   L22166918
# 1  North of Clarence River Mouth, Kaikōura NZ-Can...   L22168688
# 3                          Kaikoura--town waterfront    L1249759
# 4  1200 Alpine Pacific Touring Route, Peketā, Can...   L22249885
# 5             Kaikoura South Coast--Oaro River Mouth   L12602431
#
#   LOCALITY TYPE   LATITUDE   LONGITUDE OBSERVATION DATE  \
# 0             P -42.458124  173.554744       2023/01/12
# 1             P -42.171416  173.932336       2023/01/12
# 3             H -42.402038  173.682518       2023/01/21
# 4             P -42.451887  173.568536       2023/01/18
# 5             H -42.513964  173.507146       2023/01/15
#
#   TIME OBSERVATIONS STARTED  APPROVED  Migration_type
# 0                  11:41:00       1.0               N
# 1                  13:16:00       1.0               N
# 3                  11:59:00       1.0               N
# 4                  11:02:00       1.0               N
# 5                  12:05:00       1.0               N
#
# [5 rows x 24 columns]

# %%
# export the cbird_filtered

# cbirds_filtered.to_csv('cbirds_filtered.csv', index=False)
import geopandas as gpd
# export the cbirds_filtered to shaply file
cbirds_filtered.dtypes
# Out:
# LAST EDITED DATE               object
# TAXONOMIC ORDER               float64
# CATEGORY                       object
# COMMON NAME                    object
# SCIENTIFIC NAME                object
# EXOTIC CODE                    object
# OBSERVATION COUNT              object
# BREEDING CODE                  object
# BREEDING CATEGORY              object
# BEHAVIOR CODE                  object
# STATE CODE                     object
# COUNTY                         object
# COUNTY CODE                    object
# IBA CODE                       object
# ATLAS BLOCK                    object
# LOCALITY                       object
# LOCALITY ID                    object
# LOCALITY TYPE                  object
# LATITUDE                      float64
# LONGITUDE                     float64
# OBSERVATION DATE               object
# TIME OBSERVATIONS STARTED      object
# APPROVED                      float64
# Migration_type                 object
# geometry                     geometry
# dtype: object

# %%
# convert cbirds_filtered to geopands
cbirds_filtered = gpd.GeoDataFrame(cbirds_filtered, geometry=gpd.points_from_xy(cbirds_filtered.LONGITUDE, cbirds_filtered.LATITUDE), crs="EPSG:2193")

# %%
cbirds_filtered.geometry
# Out:
# 0        POINT (173.555 -42.458)
# 1        POINT (173.932 -42.171)
# 3        POINT (173.683 -42.402)
# 4        POINT (173.569 -42.452)
# 5        POINT (173.507 -42.514)
#                   ...
# 75021    POINT (172.369 -43.798)
# 75022    POINT (172.487 -43.643)
# 75023    POINT (172.007 -43.518)
# 75024    POINT (172.228 -43.621)
# 75025    POINT (172.215 -43.604)
# Name: geometry, Length: 74997, dtype: geometry

# %%
cbirds_filtered.to_crs(epsg=2193, inplace=True)

# %%
cbirds_filtered.head()
# Out:
#   LAST EDITED DATE  TAXONOMIC ORDER CATEGORY          COMMON NAME  \
# 0       2023/01/11           6851.0     spuh        albatross sp.
# 1       2023/01/11           6851.0     spuh        albatross sp.
# 3       2023/12/11           7167.0  species  Australasian Gannet
# 4       2023/01/18           7167.0  species  Australasian Gannet
# 5       2023/10/17           7167.0  species  Australasian Gannet
#
#    SCIENTIFIC NAME EXOTIC CODE OBSERVATION COUNT BREEDING CODE  \
# 0  Diomedeidae sp.         NaN                 1           NaN
# 1  Diomedeidae sp.         NaN                 4           NaN
# 3   Morus serrator         NaN                 1           NaN
# 4   Morus serrator         NaN                 1           NaN
# 5   Morus serrator         NaN                 2           NaN
#
#   BREEDING CATEGORY BEHAVIOR CODE  ...  \
# 0               NaN           NaN  ...
# 1               NaN           NaN  ...
# 3               NaN           NaN  ...
# 4               NaN           NaN  ...
# 5               NaN           NaN  ...
#
#                                             LOCALITY LOCALITY ID  \
# 0  Hikurangi Marine Reserve, Kaikōura NZ-Canterbu...   L22166918
# 1  North of Clarence River Mouth, Kaikōura NZ-Can...   L22168688
# 3                          Kaikoura--town waterfront    L1249759
# 4  1200 Alpine Pacific Touring Route, Peketā, Can...   L22249885
# 5             Kaikoura South Coast--Oaro River Mouth   L12602431
#
#   LOCALITY TYPE   LATITUDE   LONGITUDE OBSERVATION DATE  \
# 0             P -42.458124  173.554744       2023/01/12
# 1             P -42.171416  173.932336       2023/01/12
# 3             H -42.402038  173.682518       2023/01/21
# 4             P -42.451887  173.568536       2023/01/18
# 5             H -42.513964  173.507146       2023/01/15
#
#   TIME OBSERVATIONS STARTED APPROVED  Migration_type                 geometry
# 0                  11:41:00      1.0               N  POINT (173.555 -42.458)
# 1                  13:16:00      1.0               N  POINT (173.932 -42.171)
# 3                  11:59:00      1.0               N  POINT (173.683 -42.402)
# 4                  11:02:00      1.0               N  POINT (173.569 -42.452)
# 5                  12:05:00      1.0               N  POINT (173.507 -42.514)
#
# [5 rows x 25 columns]

# %%
# filter the common_name col contain' albatross'
albatross = cbirds_filtered[cbirds_filtered['COMMON NAME'].str.contains('albatross')]

# %%
albatross['COMMON NAME'].value_counts()

# %%
cbirds_filtered[cbirds_filtered['COMMON NAME'].str.contains('shearwater')]

# %%
df = pd.DataFrame(
    {
        "City": ["Buenos Aires", "Brasilia", "Santiago", "Bogota", "Caracas"],
        "Country": ["Argentina", "Brazil", "Chile", "Colombia", "Venezuela"],
        "Latitude": [-34.58, -15.78, -33.45, 4.60, 10.48],
        "Longitude": [-58.66, -47.91, -70.66, -74.08, -66.86],
    }
)

# %%
df_1 = gpd.GeoDataFrame(df, geometry=gpd.points_from_xy(df.Longitude, df.Latitude),crs="EPSG:4326")

# %%
df_1.info
# Out:
# <bound method DataFrame.info of            City    Country  Latitude  Longitude               geometry
# 0  Buenos Aires  Argentina    -34.58     -58.66  POINT (-58.66 -34.58)
# 1      Brasilia     Brazil    -15.78     -47.91  POINT (-47.91 -15.78)
# 2      Santiago      Chile    -33.45     -70.66  POINT (-70.66 -33.45)
# 3        Bogota   Colombia      4.60     -74.08     POINT (-74.08 4.6)
# 4       Caracas  Venezuela     10.48     -66.86   POINT (-66.86 10.48)>

# %%
df_1.to_crs(epsg=2193)
# Out:
#            City    Country  Latitude  Longitude  \
# 0  Buenos Aires  Argentina    -34.58     -58.66
# 1      Brasilia     Brazil    -15.78     -47.91
# 2      Santiago      Chile    -33.45     -70.66
# 3        Bogota   Colombia      4.60     -74.08
# 4       Caracas  Venezuela     10.48     -66.86
#
#                             geometry
# 0   POINT (6502376.434 -4670177.098)
# 1   POINT (6332820.821 -7724222.903)
# 2   POINT (7775148.355 -3764618.406)
# 3  POINT (11695283.635 28681998.253)
# 4   POINT (9633328.137 27741321.239)
